# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('Forex_sample_predictions.csv')

# %%
data.head()
# Out:
#    prediction    actual
# 0    1.751927  1.752667
# 1    1.751909  1.752812
# 2    1.751996  1.753013
# 3    1.752173  1.752934
# 4    1.752230  1.753064
